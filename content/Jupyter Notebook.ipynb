# %% [markdown]
# # Jupyter Notebook
#
# 是一个基于网页的功能强大的交互式编辑器
# 支持图片![cartman.jpg](attachment:cartman.jpg)（不过有个问题，比如我在家里拉取这个仓库，还能看到这个图片吗？如果能看到，那么图片存在哪里？）
# 支持运行代码（python,Julia和R语言），其ipynb后缀文档以json格式保存。
